# %% [markdown]
# <a href="https://colab.research.google.com/github/LittleKzin/Littlekzin/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Meu primeiro codigo

# %%
print("Ola seja bem vindo a Little Machine")
print("digite a senha Pls")
print("bota a senha ai zé ruela...")

# verificação de senha
senha_permitida = "yammers"
senha_usuario = input("digite a senha:")

# verificar senha esta correta
if senha_usuario == senha_permitida:
    print("senha aceita")
    print("Mas agora tem a 2° etapa")
    print("qual a idade do usuario ?")

    # verificação de idade
    idade_permitida = 20
    idade_usuario_str = input("digite a idade:")

    # Tenta converter a idade para inteiro
    try:
        idade_usuario = int(idade_usuario_str)
    except ValueError:
        print("Idade inválida. Por favor, digite um número.")
        exit() # Finaliza o programa se a idade não for um número

    # verificar se a idade está correta
    if idade_usuario == idade_permitida:
        print("idade aceita")
        print("Ma tu ta velho em kkkkk")
        print("Sistema: BEM VINDO A LITTLE MACHINE")
    else:
        print("Essa não é a idade otario kk")
        print("Programa finalizado.")
        exit() # Finaliza o programa se a idade estiver incorreta
else:
    print("Essa não é a senha otario kk")
    print("Programa finalizado.")
    exit() # Finaliza o programa se a senha estiver incorreta

# %%
print("ola meu chapa")
